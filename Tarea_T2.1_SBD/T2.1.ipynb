# %% [markdown]
# # T2.1: Exercicio CSV con PANDAS

# %% [markdown]
# Práctica de lectura de arquivos CSV e conversión. Terás que completar o seguinte código de exemplo onde corresponda.
#
# Utiliza como dataset os arquivos CSV dos centros educativos en Galicia: <https://www.edu.xunta.gal/centroseducativos/>
#
# Importar a libraría **pandas** (lembra instalala con conda se non a tes: `conda install pandas`)

# %%
import pandas as pd
import os, tempfile

# %% [markdown]
# Ler ficheiro CSV e gardalo un dataframe:

# %%
coruna_df = pd.read_csv("C:/Users/gabriel.antonio.edre/Documents/main/GIT/Tareas_SBD/Tarea_T2.1_SBD/acoruna.csv")

# %% [markdown]
# **Completa**:

# %%
lugo_df = pd.read_csv("C:/Users/gabriel.antonio.edre/Documents/main/GIT/Tareas_SBD/Tarea_T2.1_SBD/lugo.csv")
ourense_df = pd.read_csv("C:/Users/gabriel.antonio.edre/Documents/main/GIT/Tareas_SBD/Tarea_T2.1_SBD/ourense.csv")
pontevedra_df = pd.read_csv("C:/Users/gabriel.antonio.edre/Documents/main/GIT/Tareas_SBD/Tarea_T2.1_SBD/pontevedra.csv")

# %% [markdown]
# **Completa**: Carga o resto de dataframes e gárdao na variable df: <https://realpython.com/pandas-merge-join-and-concat/>

# %%
df = pd.concat([coruna_df, lugo_df, ourense_df, pontevedra_df], ignore_index = True)

# %% [markdown]
# Amosar o dataframe

# %%
df
# Out:
#         Código                                          Nome  \
# 0     15000016                   CEIP Plurilingüe San Marcos
# 1     15000107                                   CEIP A Maía
# 2     15000132                          CPR Plurilingüe Alca
# 3     15000338                               CPI As Mirandas
# 4     15000363                         CEIP Ponte dos Brozos
# ...        ...                                           ...
# 1634  36025220                              CAD FDYE-Galicia
# 1635  36025232  CEMU Profesional Agrupación Musical do Rosal
# 1636  36025244                        CPR Nortempo Formación
# 1637  36025256                     CPR Big Formación Peniche
# 1638  36025268                  EMUSPR de Salvaterra de Miño
#
#                                   Enderezo            Concello   Provincia  \
# 0                       Campo da Feira s/n            Abegondo    A Coruña
# 1         Rúa Peregrina, s/n (Bertamiráns)                Ames    A Coruña
# 2               Lugar Biduído de Arriba 36                Ames    A Coruña
# 3          Avenida Celso Emilio Ferreiro 4                Ares    A Coruña
# 4     Avenida Arsenio Iglesias, 34 (Sabon)             Arteixo    A Coruña
# ...                                    ...                 ...         ...
# 1634               Avenida das Camelias 53                Vigo  Pontevedra
# 1635            Rúa Couso, s/n - Auditorio             O Rosal  Pontevedra
# 1636                         Rúa Ourense 2                Vigo  Pontevedra
# 1637                      Rúa López Mora 2                Vigo  Pontevedra
# 1638              Rúa Rosalía de Castro 78  Salvaterra de Miño  Pontevedra
#
#       Cód. postal   Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y  \
# 0         15318.0  881880201           CEIP     43.229183     -8.286580
# 1         15220.0  881866002           CEIP     42.867485     -8.657342
# 2         15895.0  981531103            CPR     42.846325     -8.600729
# 3         15624.0  881930020            CPI     43.429363     -8.246173
# 4         15142.0  881960506           CEIP     43.306938     -8.510333
# ...           ...        ...            ...           ...           ...
# 1634      36211.0  680831166            CAD     -8.729750     42.229722
# 1635      36770.0        NaN           CEMU     -8.835709     41.934625
# 1636      36211.0  900104220            CPR     -8.730249     42.225970
# 1637      36208.0        NaN            CPR      0.000000      0.000000
# 1638      36450.0        NaN         EMUSPR     -8.499848     42.083714
#
#      TITULARIDADE ENSINO_CONCERTADO DEPENDENTE
# 0         Pública               Non         Si
# 1         Pública               Non         Si
# 2         Privada                Si        Non
# 3         Pública               Non         Si
# 4         Pública               Non         Si
# ...           ...               ...        ...
# 1634      Privada               Non        Non
# 1635      Privada               Non        Non
# 1636      Privada               Non        Non
# 1637      Privada               Non        Non
# 1638      Privada               Non        Non
#
# [1639 rows x 13 columns]

# %% [markdown]
# Amosar as primeiras filas do dataframe (cabeceira)

# %%
df.head()
# Out:
#      Código                         Nome  \
# 0  15000016  CEIP Plurilingüe San Marcos
# 1  15000107                  CEIP A Maía
# 2  15000132         CPR Plurilingüe Alca
# 3  15000338              CPI As Mirandas
# 4  15000363        CEIP Ponte dos Brozos
#
#                                Enderezo  Concello Provincia  Cód. postal  \
# 0                    Campo da Feira s/n  Abegondo  A Coruña      15318.0
# 1      Rúa Peregrina, s/n (Bertamiráns)      Ames  A Coruña      15220.0
# 2            Lugar Biduído de Arriba 36      Ames  A Coruña      15895.0
# 3       Avenida Celso Emilio Ferreiro 4      Ares  A Coruña      15624.0
# 4  Avenida Arsenio Iglesias, 34 (Sabon)   Arteixo  A Coruña      15142.0
#
#     Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# 0  881880201           CEIP     43.229183     -8.286580      Pública
# 1  881866002           CEIP     42.867485     -8.657342      Pública
# 2  981531103            CPR     42.846325     -8.600729      Privada
# 3  881930020            CPI     43.429363     -8.246173      Pública
# 4  881960506           CEIP     43.306938     -8.510333      Pública
#
#   ENSINO_CONCERTADO DEPENDENTE
# 0               Non         Si
# 1               Non         Si
# 2                Si        Non
# 3               Non         Si
# 4               Non         Si

# %% [markdown]
# Amosar as últimas filas do dataframe

# %%
df.tail()
# Out:
#         Código                                          Nome  \
# 1634  36025220                              CAD FDYE-Galicia
# 1635  36025232  CEMU Profesional Agrupación Musical do Rosal
# 1636  36025244                        CPR Nortempo Formación
# 1637  36025256                     CPR Big Formación Peniche
# 1638  36025268                  EMUSPR de Salvaterra de Miño
#
#                         Enderezo            Concello   Provincia  Cód. postal  \
# 1634     Avenida das Camelias 53                Vigo  Pontevedra      36211.0
# 1635  Rúa Couso, s/n - Auditorio             O Rosal  Pontevedra      36770.0
# 1636               Rúa Ourense 2                Vigo  Pontevedra      36211.0
# 1637            Rúa López Mora 2                Vigo  Pontevedra      36208.0
# 1638    Rúa Rosalía de Castro 78  Salvaterra de Miño  Pontevedra      36450.0
#
#        Teléfono Tipo de centro  COORDENADA_X  COORDENADA_Y TITULARIDADE  \
# 1634  680831166            CAD     -8.729750     42.229722      Privada
# 1635        NaN           CEMU     -8.835709     41.934625      Privada
# 1636  900104220            CPR     -8.730249     42.225970      Privada
# 1637        NaN            CPR      0.000000      0.000000      Privada
# 1638        NaN         EMUSPR     -8.499848     42.083714      Privada
#
#      ENSINO_CONCERTADO DEPENDENTE
# 1634               Non        Non
# 1635               Non        Non
# 1636               Non        Non
# 1637               Non        Non
# 1638               Non        Non

# %% [markdown]
# Amosar a "forma" ou dimensións do dataframe (filas e columnas)

# %%
df.shape
# Out:
# (1639, 13)

# %% [markdown]
# Amosar algunhas estatísticas por defecto

# %%
df.describe()
# Out:
#              Código   Cód. postal  COORDENADA_X  COORDENADA_Y
# count  1.639000e+03   1638.000000   1639.000000   1639.000000
# mean   2.657808e+07  27002.887668     35.420011     -1.359246
# std    9.286126e+06   9304.941902     17.882334     17.449197
# min    1.500002e+07  15001.000000    -13.488744     -9.269669
# 25%    1.502641e+07  15701.000000     42.208822     -8.689238
# 50%    2.702094e+07  27875.000000     42.517906     -8.400874
# 75%    3.601115e+07  36214.000000     43.021791     -7.566911
# max    3.602527e+07  36995.000000     43.738419     43.741764

# %%
# seleccionar a columna de "Concello" como serie
df['Concello']

# mostrar o tipo de selección
type(df['Concello'])

# Outro xeito de seleccionar series
df.TITULARIDADE

# mostrar o tipo de selección
type(df.Concello)

#seleccionar a columna de "Nome" como Dataframe
df[['Nome']]

# mostrar o tipo de selección
type(df[['Nome']])

# seleccionar varias columnas "Código" e "Nome"
df[['Código','Nome']]

# Mirar o tipo do resultado
type(df[['Código','Nome']])

# Mirar o tipo do argumento que lle pasas a df para facer a selección ['elemento1','elemento2']
type(['Código','Nome'])
# Out:
# list

# %% [markdown]
# A completar tamén:

# %%
# A resolver, pista: <https://www.geeksforgeeks.org/selecting-rows-in-pandas-dataframe-based-on-conditions/>

# Seleccionar centros que sexan de titularidade privada. Cantos hai?
# privados_df = df[(df.TITULARIDADE == 'Privada')]
# privados_df.head(500)
# print(len(privados_df))

# Seleccionar centros que teñan ensinanzas concertados. Cantos hai?
# concertados_df = df[(df.ENSINO_CONCERTADO == 'Si')]
# concertados_df.head(500)
# print(len(concertados_df))

# Hai algún centro con ensinanzas concertadas dependente da Consellería?
# concertadosDependientes_df = concertados_df[(concertados_df.DEPENDENTE == 'Si')]
# concertadosDependientes_df.head(500)
# print(len(concertadosDependientes_df)) #No parece haber ningún concertado dependiente

# Seleccionar centros de titularidade pública de Coruña. Cantos hai?
# publicos_df = df[(df.TITULARIDADE == 'Pública') & (df.Provincia == 'A Coruña')]
# publicos_df.head(500)
# print(len(publicos_df))

# Seleccionar centros de titularidade pública de Lugo. Cantos hai?
# publicos_df = df[(df.TITULARIDADE == 'Pública') & (df.Provincia == 'Lugo')]
# publicos_df.head(500)
# print(len(publicos_df))

# Seleccionar centros de titularidade pública de Ourense. Cantos hai?
# publicos_df = df[(df.TITULARIDADE == 'Pública') & (df.Provincia == 'Ourense')]
# publicos_df.head(500)
# print(len(publicos_df))

# Seleccionar centros de titularidade pública de Pontevedra. Cantos hai?
# publicos_df = df[(df.TITULARIDADE == 'Pública') & (df.Provincia == 'Pontevedra')]
# publicos_df.head(500)
# print(len(publicos_df))

# Seleccionar centros de tipo: CIFP de cada unha das catro provincias. Cantos hai?
# CIFP_df = df[(df['Tipo de centro'] == 'CIFP')]
# CIFP_df.head(500)
# print(len(CIFP_df))

# Seleccionar centros de tipo: CPI, CEIP e IES de cada unha das catro provincias. Cantos hai?
# tipoCentro_df = df[(df['Tipo de centro'] == 'CPI') | (df['Tipo de centro'] == 'CEIP') | (df['Tipo de centro'] == 'IES')]
# tipoCentro_df.head(500)
# print(len(tipoCentro_df))

# Seleccionar o número de centros por concello.
# centroProvincia_df = df.groupby('Provincia')['Código'].size()
# centroProvincia_df.head(500)

# Seleccionar o número de centros de cada tipo por concello.
# tipoCentroProvincia_df = df.groupby(['Provincia', 'Tipo de centro'])['Código'].size()
# tipoCentroProvincia_df.head(500)

# Limpando datos con erros: Dime qué podes limpar e como nestes datos.
# df = df.dropna()
# df.head(500)

# %% [markdown]
# Garda o dataframe total resultante nos seguintes formatos (e logo volve abrilo nese formato e mostra a cabeceira):
#
# **CSV**

# %%
arquivo_temporal = os.path.join(tempfile.mktemp())

df.to_csv(arquivo_temporal)

print(arquivo_temporal)
# Out:
# C:\Users\GABRIE~1.EDR\AppData\Local\Temp\tmp59dbbh4c

# %% [markdown]
# **Excel**
#
# Pasa a formato excel.

# %%
df.to_excel('archivo.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.to_excel('archivo.xlsx', index=False)
#
# File c:\Users\gabriel.antonio.edre\AppData\Local\miniconda3\envs\bigdata\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\gabriel.antonio.edre\AppData\Local\miniconda3\envs\bigdata\Lib\site-packages\pandas\core\generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File c:\Users\gabriel.antonio.edre\AppData\Local\miniconda3\envs\bigdata\Lib\site-packages\pandas\io\formats\excel.py:943, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     941     need_save = False
#     942 else:
# --> 943     writer = ExcelWriter(
#     944         writer,
#     945         engine=engine,
#     946         storage_options=storage_options,
#     947         engine_kwargs=engine_kwargs,
#     948     )
#     949     need_save = True
#     951 try:
#
# File c:\Users\gabriel.antonio.edre\AppData\Local\miniconda3\envs\bigdata\Lib\site-packages\pandas\io\excel\_openpyxl.py:57, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      44 def __init__(
#      45     self,
#      46     path: FilePath | WriteExcelBuffer | ExcelWriter,
#    (...)
#      55 ) -> None:
#      56     # Use the openpyxl module as the Excel writer.
# ---> 57     from openpyxl.workbook import Workbook
#      59     engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
#      61     super().__init__(
#      62         path,
#      63         mode=mode,
#    (...)
#      66         engine_kwargs=engine_kwargs,
#      67     )
#
# ModuleNotFoundError: No module named 'openpyxl'

# %% [markdown]
# **JSON**
#
# Pasa a formato JSON.
#
# (Coidado cos índices se xuntaches os dataframes)

# %% [markdown]
# **XML**
#
# Pasa a formato XML:

# %% [markdown]
# **PARQUET**
#
# Pasa a formato parquet. Podes precisar as dependencias para **.parquet**:
#
#     `conda install pyarrow fastparquet´
